# %%
a = int (input("Enter the 1st Number"))
b = int (input("Enter the 2nd Number"))
c = int (input("Enter the 3rd Number"))

if a>=b and a>=c:
    print("The larged number of 1st input",a)
elif b>=a and b>=c:
     print("The larged number of 2nd input",b)
   
else:
    print("The larged number of 3rd input",c)

# %%
a = int (input("Enter the 1st number"))
b = int (input("Enter the 2nd number"))
c = int (input("Enter the 3rd number"))

largest_number = max (a,b,c)
print ("The larged number is(s):")
if a==largest_number:
    print("1st input",a)
if b==largest_number:
    print("2nd input",b)
if c==largest_number:
    print("3rd number",c)

# %%
n = int (input("Enter your input number"))
for i in range(1,n+):
    if i % 2==)
    print (i)
